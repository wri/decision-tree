# %% [markdown]
# # Pull Polygons from TerraMatch API (Simple)
#
# This notebook sets up the process to pull polygon geometries and metadata from the TerraMatch API.
#
# Updated to include indicators and simplify preprocessing

# %%
import yaml
import pandas as pd
from tm_api_utils import pull_tm_api_data, patch_tm_api_data
from tqdm import tqdm
import json
import sys
from datetime import datetime
sys.path.append('../src/')
import api_utils as api
import process_tm_api_results as clean

# %% [markdown]
# ## Set file paths

# %%
## PARAMS
# Naming convention
run_dir = 'ppc'
run_name = 'ppc_2025_batch1'

# Today's date
today = datetime.today().strftime('%Y-%m-%d') # Check computer date before running (if out of sync, run sudo hwclock -s)

# %%
## FILES
# Input Files
# List of approved projects
approved_projects_file = '../projects_all_approved_202502211226.csv'

# Output Files
# JSON file to store the results of the TM API pull; read it back in to clean the results (outfile, infile)
tm_api_pull_results_file = f'../data/{run_dir}/tm_api_response_prod_{run_name}_{today}.json'

# CSV file to save the results of the TM API pull
polygon_features_file = f'../data/{run_dir}/tm_api_{run_name}_{today}.csv'

# %% [markdown]
# ## Set up token & API URL

# %%
# Set up token access
auth_path = '../secrets.yaml'
with open(auth_path) as auth_file:
    auth = yaml.safe_load(auth_file)
headers = {
    'Authorization': f"Bearer {auth['access_token']}"
    }

# %%
# TerraMatch API URLs
staging_url = "https://api-staging.terramatch.org/research/v3/sitePolygons?" # Use for testing queries
prod_url = "https://api.terramatch.org/research/v3/sitePolygons?" # Use to pull data for analysis

# %% [markdown]
# ## Create list of projects to pull

# %%
# Read in list of approved projects (2025-02-21)
full = pd.read_csv(approved_projects_file)

# %%
# Create lists of projects by Cohort (and split cohort 1 into projects within the TF landscapes and outside of the TF landscapes)
cohort1 = full[full['cohort'] == 'terrafund']
cohort1_landscapes = cohort1[cohort1['country'].isin(['BI', 'CD', 'RW', 'KE', 'GH'])]
cohort1_non_landscapes = cohort1[~cohort1['country'].isin(['BI', 'CD', 'RW', 'KE', 'GH'])]
cohort2 = full[full['cohort'] == 'terrafund-landscapes']

ppc = full[full['cohort'] == 'ppc']

# %%
# Create a list of project ids to query
ids = list(set(ppc.project_id))
len(ids)

# Create a short list of ids for testing 
ids = ['244eaf7e-e109-47b2-b84e-9ebe24508391', '24d8c9a2-b8ef-481c-930b-78c9aeaf239e', 'f17dd6cf-8187-4edd-895e-07013d4990c9', '1115dda6-0165-4099-b52f-0ac53595c3a9',
       '465f543e-d53a-4356-ae8d-9790aa42d30e', 'ad149677-7ee0-479c-8d23-aa8c3bf58532', '1977b649-908c-46c3-836d-f4f6485427c2', '6d9089aa-2a6f-4dc0-8064-32c5b67ffed6']
len(ids)
# Out:
# 8

# %% [markdown]
# ## Pull projects from TerraMatch API

# %%
results = api.pull_wrapper(prod_url, headers, ids, outfile=tm_api_pull_results_file)
# Out:
# Pulling Projects: 100%|██████████| 8/8 [00:39<00:00,  4.94s/project]
# Results saved to ../data/ppc/tm_api_response_prod_ppc_2025_batch1_2025-05-22.json

# %% [markdown]
# ## Parse and save the API output

# %%
# Load the saved JSON file
with open(tm_api_pull_results_file, 'r') as file:
    results = json.load(file)

# %%
results_df = api.parse_tm_api_results(results, outfile=None, parse_indicators=True)
results_df
# Out:
#                                project_id  \
# 0    244eaf7e-e109-47b2-b84e-9ebe24508391
# 1    244eaf7e-e109-47b2-b84e-9ebe24508391
# 2    244eaf7e-e109-47b2-b84e-9ebe24508391
# 3    244eaf7e-e109-47b2-b84e-9ebe24508391
# 4    244eaf7e-e109-47b2-b84e-9ebe24508391
# ..                                    ...
# 897  6d9089aa-2a6f-4dc0-8064-32c5b67ffed6
# 898  6d9089aa-2a6f-4dc0-8064-32c5b67ffed6
# 899  6d9089aa-2a6f-4dc0-8064-32c5b67ffed6
# 900  6d9089aa-2a6f-4dc0-8064-32c5b67ffed6
# 901  6d9089aa-2a6f-4dc0-8064-32c5b67ffed6
#
#                                   poly_id  \
# 0    67931b60-9df4-45cd-818e-ff7ddfaf11fc
# 1    ecf4d885-4b74-45f0-b6b0-21cc82820fa2
# 2    b843c681-acb8-4e71-a488-df238e875766
# 3    0fb77a06-012a-4743-a5f2-2ca8eb40abed
# 4    bb119f02-dbc3-4cf4-a688-b248107f3b18
# ..                                    ...
# 897  24ef5fa3-32ae-4e49-99a7-1b6113cd4970
# 898  95ae69a5-5b0b-4d45-8a47-c12c44acc0bb
# 899  3cc90a06-8844-4bc6-ba1f-22c8f50c475f
# 900  7d7a8d13-2458-43db-8d09-3972bcbe476d
# 901  79f611d2-4f5d-487b-9c32-efe188e16e19
#
#                                   site_id  \
# 0    b9bdfd4f-7eaa-41c9-b0b6-761d3b449628
# 1    060e7825-e8f6-4fc6-8879-c387e5431194
# 2    b9bdfd4f-7eaa-41c9-b0b6-761d3b449628
# 3    0f8a4317-b4c1-4c89-86a0-ef714e334e1f
# 4    0f8a4317-b4c1-4c89-86a0-ef714e334e1f
# ..                                    ...
# 897  d602dc8a-f188-4307-8aea-daa421eaffec
# 898  c15fb3c1-8ebb-421d-ae61-c8b45625f76d
# 899  c15fb3c1-8ebb-421d-ae61-c8b45625f76d
# 900  bc41d56a-c5dd-482e-8be0-7cf0a1b9a1c8
# 901  a0d39a14-9fbc-4351-ada2-a8913d3c7673
#
#                                               geometry  plantstart plantend  \
# 0    {'type': 'Polygon', 'coordinates': [[[-45.7849...  2022-03-15     None
# 1    {'type': 'Polygon', 'coordinates': [[[-45.6703...  2022-03-15     None
# 2    {'type': 'Polygon', 'coordinates': [[[-45.7782...  2022-03-15     None
# 3    {'type': 'Polygon', 'coordinates': [[[-45.8229...  2022-03-15     None
# 4    {'type': 'Polygon', 'coordinates': [[[-45.8486...  2022-03-15     None
# ..                                                 ...         ...      ...
# 897  {'type': 'Polygon', 'coordinates': [[[37.59034...  2023-09-29     None
# 898  {'type': 'Polygon', 'coordinates': [[[37.52194...  2024-11-14     None
# 899  {'type': 'Polygon', 'coordinates': [[[37.54187...  2024-11-14     None
# 900  {'type': 'Polygon', 'coordinates': [[[37.57673...  2024-12-06     None
# 901  {'type': 'Polygon', 'coordinates': [[[37.51598...  2023-10-23     None
#
#           practice      target_sys  dist project_phase  \
# 0    tree-planting    silvopasture  full
# 1    tree-planting      agroforest  full
# 2    tree-planting    silvopasture  full
# 3    tree-planting      agroforest  full
# 4    tree-planting      agroforest  full
# ..             ...             ...   ...           ...
# 897  tree-planting  natural-forest  full
# 898  tree-planting  natural-forest  full
# 899  tree-planting  natural-forest  full
# 900  tree-planting  natural-forest  full
# 901  tree-planting  natural-forest  full
#
#                                        tree_cover_loss  \
# 0    {'indicatorSlug': 'treeCoverLoss', 'yearOfAnal...
# 1    {'indicatorSlug': 'treeCoverLoss', 'yearOfAnal...
# 2    {'indicatorSlug': 'treeCoverLoss', 'yearOfAnal...
# 3    {'indicatorSlug': 'treeCoverLoss', 'yearOfAnal...
# 4    {'indicatorSlug': 'treeCoverLoss', 'yearOfAnal...
# ..                                                 ...
# 897  {'indicatorSlug': 'treeCoverLoss', 'yearOfAnal...
# 898                                                NaN
# 899                                                NaN
# 900                                                NaN
# 901                                                NaN
#
#                                  tree_cover_loss_fires  \
# 0    {'indicatorSlug': 'treeCoverLossFires', 'yearO...
# 1    {'indicatorSlug': 'treeCoverLossFires', 'yearO...
# 2    {'indicatorSlug': 'treeCoverLossFires', 'yearO...
# 3    {'indicatorSlug': 'treeCoverLossFires', 'yearO...
# 4    {'indicatorSlug': 'treeCoverLossFires', 'yearO...
# ..                                                 ...
# 897  {'indicatorSlug': 'treeCoverLossFires', 'yearO...
# 898                                                NaN
# 899                                                NaN
# 900                                                NaN
# 901                                                NaN
#
#                                restoration_by_strategy  \
# 0    {'indicatorSlug': 'restorationByStrategy', 'ye...
# 1    {'indicatorSlug': 'restorationByStrategy', 'ye...
# 2    {'indicatorSlug': 'restorationByStrategy', 'ye...
# 3    {'indicatorSlug': 'restorationByStrategy', 'ye...
# 4    {'indicatorSlug': 'restorationByStrategy', 'ye...
# ..                                                 ...
# 897  {'indicatorSlug': 'restorationByStrategy', 'ye...
# 898  {'indicatorSlug': 'restorationByStrategy', 'ye...
# 899  {'indicatorSlug': 'restorationByStrategy', 'ye...
# 900  {'indicatorSlug': 'restorationByStrategy', 'ye...
# 901  {'indicatorSlug': 'restorationByStrategy', 'ye...
#
#                                restoration_by_land_use
# 0    {'indicatorSlug': 'restorationByLandUse', 'yea...
# 1    {'indicatorSlug': 'restorationByLandUse', 'yea...
# 2    {'indicatorSlug': 'restorationByLandUse', 'yea...
# 3    {'indicatorSlug': 'restorationByLandUse', 'yea...
# 4    {'indicatorSlug': 'restorationByLandUse', 'yea...
# ..                                                 ...
# 897  {'indicatorSlug': 'restorationByLandUse', 'yea...
# 898  {'indicatorSlug': 'restorationByLandUse', 'yea...
# 899  {'indicatorSlug': 'restorationByLandUse', 'yea...
# 900  {'indicatorSlug': 'restorationByLandUse', 'yea...
# 901  {'indicatorSlug': 'restorationByLandUse', 'yea...
#
# [902 rows x 14 columns]

# %%
results_df.to_csv(polygon_features_file, index=False)
