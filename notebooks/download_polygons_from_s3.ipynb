# %%
from pathlib import Path
import sys
sys.path.append('../src')
import s3_utils as s3

# %% [markdown]
# ## Set directory and file paths

# %%
s3_base = 's3://restoration-monitoring/tree_verification/output/project_data/'
run_dir = 'maxar_spenddown'
local_base = f'../data/{run_dir}/'

# %%
# Projects list 'CAR_22_EEDD'
projects = ['KEN_22_DREK', 'RWA_22_SE', 'UGA_22_SWAGEN', 'UGA_22_PANR', 'NIG_22_NCF', 'ETH_22_WVE', 'ETH_22_SUNARMA', 'RWA_22_RECOR', 'CIV_22_SOSFORETS',
            'KEN_22_KENVO', 'NIG_22_IITA', 'TGO_22_ADHD']

# %% [markdown]
# ## Sync project_data from s3

# %%
combined_gdf = s3.process_projects(projects, s3_base, local_base)
# Out:
# [INFO] Processing project KEN_22_DREK
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 combined_gdf = s3.process_projects(projects, s3_base, local_base)
#
# File ~/github_repos/terrafund-portfolio-analyses/notebooks/../src/s3_utils.py:75, in process_projects(projects, s3_base, local_base)
#      72 print(f"[INFO] Processing project {project}")
#      74 # Step 1: List and select latest file
# ---> 75 files = list_s3_geojson_files(s3_geojson_path, project)
#      76 latest_file = get_latest_geojson_filename(files, project)
#      78 # Step 2: Download
#
# File ~/github_repos/terrafund-portfolio-analyses/notebooks/../src/s3_utils.py:15, in list_s3_geojson_files(s3_geojson_path, project_name)
#      12 result = subprocess.run(['aws', 's3', 'ls', s3_geojson_path], capture_output=True, text=True)
#      14 if result.returncode != 0:
# ...

# %%
s3://restoration-monitoring/tree_verification/output/project_data/CAR_22_EEDD/geojson/
s3://restoration-monitoring/tree_verification/output/project_data/CAR_22_EEDD/geojson
